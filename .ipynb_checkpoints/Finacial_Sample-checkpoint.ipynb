# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests, time
from pymongo import MongoClient
import pymongo
from pprint import pprint
import csv
import json
from io import StringIO
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Fetch Data from API and Insert into MongoDB:

# Check Connection to Database
try: 
    MongoClient() 
    print("Database Connected successfully!!!") 
except:   
    print("Could not connect to MongoDB") 



# Connect to MongoDB
connectionString = "mongodb+srv://admin:Password123@financialcluster.i4eijkg.mongodb.net"
cluster = MongoClient(connectionString)
db = cluster['financialDB']
collection = db['financial']

api_url = "https://financial-data-api.laurelanalytiq.com/data.json"
response = requests.get(api_url)
data = response.json()

#print(data)
# Fetch data from MongoDB and convert it into a DataFrame
#mongo_data = list(collection.find({}))
mongo_data = list(data)
# Now you have your data in the DataFrame 'df'
df = pd.DataFrame(mongo_data)
df



#Pseudo-batch process

# while True:
#     # Fetch data from API
#     api_url = "https://financial-data-api.laurelanalytiq.com/data.json"
#     response = requests.get(api_url)
#     if response.status_code == 200:
#         data = response.json()
#         try: 
#             # Insert data into MongoDB
#             collection.insert_many(data)
#             print("Data Successfully uploaded to Database")
#         except: 
#             print("Error uploading data")
#         #print(data)
#         time.sleep(1440)
# else:
#     exit()
# Out:
# Database Connected successfully!!!
#     Index           Segment                   Country     Product  \
# 0       0        Government                    France      Paseo
# 1       1         Midmarket                    France      Paseo
# 2       2        Government                    Canada        VTT
# 3       3        Government                    France      Paseo
# 4       4        Government                    France       Velo
# ..    ...               ...                       ...         ...
# 638   638        Government                    Canada      Paseo
# 639   639        Government                    Mexico    Montana
# 640   640  Channel Partners  United States of America        VTT
# 641   641    Small Business                    Mexico   Amarilla
# 642                     NaN                       NaN         NaN
#
#     Discount Band Units Sold Manufacturing Price  Sale Price  Gross Sales  \
# 0            Low        3945                10.0          7.0     27615.0
# 1            Low        2296                10.0         15.0     34440.0
# 2            Low        1326               250.0          7.0      9282.0
# 3            Low        1030                10.0          7.0      7210.0
# 4            Low         639               120.0          7.0      4473.0
# ..            ...        ...                 ...          ...         ...
# 638         High         723                10.0          7.0      5061.0
# 639         High        1368                 5.0          7.0      9576.0
# 640         High        1806               250.0         12.0     21672.0
# 641         High         546               260.0        300.0    163800.0
# 642           NaN        NaN                 NaN          NaN         NaN
#
#     Discounts     Sales Cost of Goods Sold   Profit        Date  Month Name  \
# 0      276.15  27338.85            19725.0  7613.85  2014-01-01    January
# 1       344.4   34095.6            22960.0  11135.6  2014-02-01   February
# 2       92.82   9189.18             6630.0  2559.18  2014-03-01      March
# 3        72.1    7137.9             5150.0   1987.9  2014-05-01        May
# 4       44.73   4428.27             3195.0  1233.27  2014-11-01   November
# ..        ...       ...                ...      ...         ...         ...
# 638    759.15   4301.85             3615.0   686.85  2014-04-01      April
# 639    1436.4    8139.6             6840.0   1299.6  2014-02-01   February
# 640    3250.8   18421.2             5418.0  13003.2  2014-05-01        May
# 641   24570.0  139230.0           136500.0   2730.0  2014-10-01    October
# 642       NaN       NaN                NaN      NaN         NaN         NaN
#
#      Year
# 0    2014
# 1    2014
# 2    2014
# 3    2014
# 4    2014
# ..    ...
# 638  2014
# 639  2014
# 640  2014
# 641  2014
# 642   NaN
#
# [643 rows x 16 columns]

# %%
# Read the Excel file into a pandas DataFrame
df = pd.read_csv('api-data.csv')

# Display the DataFrame
df.head(20)
# Out:
#     Index           Segment                   Country      Product  \
# 0       0        Government                    France       Paseo
# 1       1         Midmarket                    France       Paseo
# 2       2        Government                    Canada         VTT
# 3       3        Government                    France       Paseo
# 4       4        Government                    France        Velo
# 5       5        Government                    Mexico   Carretera
# 6       6        Government  United States of America   Carretera
# 7       7  Channel Partners  United States of America   Carretera
# 8       8        Enterprise  United States of America   Carretera
# 9       9  Channel Partners                    Canada   Carretera
# 10     10  Channel Partners                   Germany   Carretera
# 11     11  Channel Partners                    France   Carretera
# 12     12    Small Business                    Mexico   Carretera
# 13     13        Government                    Mexico   Carretera
# 14     14        Government                    France     Montana
# 15     15         Midmarket                    Mexico     Montana
# 16     16        Government                    France   Carretera
# 17     17    Small Business  United States of America     Montana
# 18     18    Small Business  United States of America     Montana
# 19     19        Enterprise  United States of America     Montana
#
#    Discount Band  Units Sold  Manufacturing Price   Sale Price   Gross Sales  \
# 0           Low       3945.0                 10.0           7.0      27615.0
# 1           Low       2296.0                 10.0          15.0      34440.0
# 2           Low       1326.0                250.0           7.0       9282.0
# 3           Low       1030.0                 10.0           7.0       7210.0
# 4           Low        639.0                120.0           7.0       4473.0
# 5           Low       1210.0                  3.0         350.0     423500.0
# 6           Low       2529.0                  3.0           7.0      17703.0
# 7           Low       1858.0                  3.0          12.0      22296.0
# 8           Low        330.0                  3.0         125.0      41250.0
# 9           Low       1445.0                  3.0          12.0      17340.0
# 10          Low        766.0                  3.0          12.0       9192.0
# 11          Low       2671.0                  3.0          12.0      32052.0
# 12          Low        494.0                  3.0         300.0     148200.0
# 13          Low       1397.0                  3.0         350.0     488950.0
# 14          Low       1375.5                  5.0          20.0      27510.0
# 15          Low       2214.0                  5.0          15.0      33210.0
# 16          Low       2155.0                  3.0         350.0     754250.0
# 17          Low       2498.0                  5.0         300.0     749400.0
# 18          Low       2301.0                  5.0         300.0     690300.0
# 19          Low        663.0                  5.0         125.0      82875.0
#
#     Discounts      Sales  Cost of Goods Sold     Profit        Date  \
# 0      276.15   27338.85             19725.0    7613.85  2014-01-01
# 1      344.40   34095.60             22960.0   11135.60  2014-02-01
# 2       92.82    9189.18              6630.0    2559.18  2014-03-01
# 3       72.10    7137.90              5150.0    1987.90  2014-05-01
# 4       44.73    4428.27              3195.0    1233.27  2014-11-01
# 5     4235.00  419265.00            314600.0  104665.00  2014-03-01
# 6      177.03   17525.97             12645.0    4880.97  2014-07-01
# 7      222.96   22073.04              5574.0   16499.04  2014-02-01
# 8      412.50   40837.50             39600.0    1237.50  2013-09-01
# 9      173.40   17166.60              4335.0   12831.60  2014-09-01
# 10      91.92    9100.08              2298.0    6802.08  2013-10-01
# 11     320.52   31731.48              8013.0   23718.48  2014-09-01
# 12    1482.00  146718.00            123500.0   23218.00  2013-10-01
# 13    4889.50  484060.50            363220.0  120840.50  2014-10-01
# 14     275.10   27234.90             13755.0   13479.90  2014-07-01
# 15     332.10   32877.90             22140.0   10737.90  2014-03-01
# 16    7542.50  746707.50            560300.0  186407.50  2014-12-01
# 17    7494.00  741906.00            624500.0  117406.00  2013-09-01
# 18    6903.00  683397.00            575250.0  108147.00  2014-04-01
# 19     828.75   82046.25             79560.0    2486.25  2013-10-01
#
#      Month Name  Year
# 0      January   2014
# 1     February   2014
# 2        March   2014
# 3          May   2014
# 4     November   2014
# 5        March   2014
# 6         July   2014
# 7     February   2014
# 8    September   2013
# 9    September   2014
# 10     October   2013
# 11   September   2014
# 12     October   2013
# 13     October   2014
# 14        July   2014
# 15       March   2014
# 16    December   2014
# 17   September   2013
# 18       April   2014
# 19     October   2013

# %%
# Check the data type of each column in the DataFrame
data_types = df.dtypes

# Print the data types
print(data_types)
# Out:
# Index                    int64
# Segment                 object
# Country                 object
# Product                 object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
#  Sale Price            float64
# Gross Sales            float64
# Discounts              float64
# Sales                  float64
# Cost of Goods Sold     float64
# Profit                 float64
# Date                    object
# Month Name              object
# Year                     int64
# dtype: object

# %%
df.columns = df.columns.str.strip()

# %%
df.describe()
# Out:
#             Index   Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count  642.000000   642.000000           642.000000  642.000000  6.420000e+02
# mean   320.500000  1608.270249            97.119938  120.526480  1.855083e+05
# std    185.473718   873.403353           108.568244  137.797292  2.571253e+05
# min      0.000000   200.000000             3.000000    7.000000  1.799000e+03
# 25%    160.250000   887.250000             5.000000   12.000000  1.745175e+04
# 50%    320.500000  1537.500000            10.000000   20.000000  3.900700e+04
# 75%    480.750000  2259.500000           250.000000  300.000000  2.826750e+05
# max    641.000000  4492.500000           260.000000  350.000000  1.207500e+06
#
#            Discounts         Sales  Cost of Goods Sold         Profit  \
# count     642.000000  6.420000e+02          642.000000     642.000000
# mean    14282.839984  1.712254e+05       147616.026480   26030.980981
# std     23643.608658  2.383121e+05       206004.271685   40679.164643
# min        18.410000  1.655080e+03          918.000000     285.600000
# 25%      1038.587500  1.598608e+04         7548.000000    3974.130000
# 50%      3083.175000  3.554020e+04        22985.000000   10911.900000
# 75%     19261.125000  2.620725e+05       247437.500000   23967.000000
# max    149677.500000  1.159200e+06       950625.000000  262200.000000
#
#               Year
# count   642.000000
# mean   2013.739875
# std       0.439044
# min    2013.000000
# 25%    2013.000000
# 50%    2014.000000
# 75%    2014.000000
# max    2014.000000

# %%
# Group by the 'category' column
grouped = df.groupby('Discounts')

# Create a scatter plot for each group
for name, group in grouped:
    plt.scatter(group['Sales'], group['Gross Sales'], label=name)

# Add labels and legend
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Scatter Plot Grouped by Category')
plt.legend()

# Show the plot
plt.show()

# %%
#bar chart comparing discount Band
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='Discount Band', data=df)

# Display count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.title('Count of Discount Band') #label
plt.xlabel('Discount Band') #x axis
plt.ylabel('Count') #y axis
plt.show()

# %%
# Group by date and sum the metrics
table_2 = df.groupby('Country').agg({
    'Profit': 'sum'
}).reset_index()

# Sort the DataFrame by profit in descending order
table_2 = table_2.sort_values(by='Profit', ascending=False)
# Print the result
print(table_2)
# Out:
#                     Country      Profit
# 0                    Canada  3474599.89
# 1                    France  3468483.29
# 2                   Germany  3376400.82
# 4  United States of America  3327464.68
# 3                    Mexico  3064941.11

# %%
# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(table_2['Country'], table_2['Profit'], color='skyblue')
plt.xlabel('Country')
plt.ylabel('Profit')
plt.title('Profit by Country')
plt.xticks(rotation=45)
plt.show()

# %%
# Group by date and sum the metrics
table_2 = df.groupby('Product').agg({
    'Profit': 'sum'
}).reset_index()


# Print the result
print(table_2)
# Out:
#        Product      Profit
# 0    Amarilla   2724817.57
# 1   Carretera   2095779.89
# 2     Montana   2084975.88
# 3       Paseo   4527125.46
# 4         VTT   2874016.02
# 5        Velo   2405174.97

# %%
# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(table_2['Profit'], labels=table_2['Product'], autopct='%1.1f%%', startangle=140)
plt.title('Profit Distribution by Product')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Group by date and product, and sum the metrics
table_3 = df.groupby('Date').agg({
    'Units Sold': 'sum',
    'Profit': 'sum',
    'Cost of Goods Sold': 'sum'
}).reset_index()

# Sort the DataFrame by date in ascending order
table_3 = table_3.sort_values(by='Date', ascending=True)

# Print the result
print(table_3)
# Out:
#           Date  Units Sold      Profit  Cost of Goods Sold
# 0   2013-09-01     47737.0   681950.53           3120887.0
# 1   2013-10-01     94932.0  1657865.10           7555016.0
# 2   2013-11-01     62844.0   752301.80           6050465.0
# 3   2013-12-01     50818.0   873779.08           4655357.0
# 4   2014-01-01     63403.0   902680.19           5756873.0
# 5   2014-02-01     47294.0   844114.89           4704594.0
# 6   2014-03-01     49543.0   670395.37           4805900.0
# 7   2014-04-01     68802.0   917450.58           5385197.5
# 8   2014-05-01     51771.0   942270.06           5381571.0
# 9   2014-06-01     78294.0  1197434.82           7348942.0
# 10  2014-07-01     61642.5   939278.19           6491103.5
# 11  2014-08-01     53902.0   831803.92           4484698.0
# 12  2014-09-01     50511.0   990217.74           4802365.0
# 13  2014-10-01    103196.0  2013068.92          10582404.0
# 14  2014-11-01     55650.0   716417.70           4779614.0
# 15  2014-12-01     92170.0  1780860.90           8864502.0

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))
# Overlay a line plot for profit
ax.plot(table_3['Date'], table_3['Cost of Goods Sold'], marker='o', color='firebrick', label='Cost of Goods Sold')
ax.plot(table_3['Date'], table_3['Profit'], marker='o', color='forestgreen', label='Profit')

# Set title and labels
ax.set_title('Over Time Performance')
ax.set_xlabel('Date')
ax.set_ylabel('Amount')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %%
# Group by date and product, and sum the metrics
table_4 = df.groupby(['Year', 'Product']).agg({
    'Units Sold': 'sum',
    'Cost of Goods Sold': 'sum'
}).reset_index()

# Sort the DataFrame by date in ascending order
table_4 = table_4.sort_values(by='Year', ascending=True)

# Print the result
print(table_4)
# Out:
#     Year      Product  Units Sold  Cost of Goods Sold
# 0   2013    Amarilla      33688.0           2737183.0
# 1   2013   Carretera      31404.0           1368097.0
# 2   2013     Montana      35935.0           3476625.0
# 3   2013       Paseo      76121.0           4139648.0
# 4   2013         VTT      40057.0           4126222.0
# 5   2013        Velo      39126.0           5533950.0
# 6   2014    Amarilla     104146.5          10794042.0
# 7   2014   Carretera     105453.5          10142271.0
# 8   2014     Montana     101042.5           8980133.0
# 9   2014       Paseo     238086.5          22079017.0
# 10  2014         VTT     115326.0          11858727.0
# 11  2014        Velo     112123.5           9533574.0

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Get unique product names
products = table_4['Product'].unique()

# Overlay area plots for each product
for product in products:
    product_data = table_4[table_4['Product'] == product]
    ax.fill_between(product_data['Year'], product_data['Cost of Goods Sold'], label=product, alpha=0.4)

# Set title and labels
ax.set_title('COGS Over Time by Product')
ax.set_xlabel('Year')
ax.set_ylabel('Cost of Goods Sold')

# Add legend with location set to 'upper left'
ax.legend(loc='upper left')


# Show plot
plt.show()

# %%
# Group by date and product, and sum the metrics
table_5 = df.groupby(['Year', 'Product']).agg({
    'Units Sold': 'sum',
    'Profit': 'sum'
}).reset_index()

# Sort the DataFrame by date in ascending order
table_5 = table_5.sort_values(by='Year', ascending=True)

# Print the result
print(table_5)
# Out:
#     Year      Product  Units Sold      Profit
# 0   2013    Amarilla      33688.0   805977.03
# 1   2013   Carretera      31404.0   209853.86
# 2   2013     Montana      35935.0   525055.54
# 3   2013       Paseo      76121.0   885250.09
# 4   2013         VTT      40057.0   821990.23
# 5   2013        Velo      39126.0   717769.76
# 6   2014    Amarilla     104146.5  1918840.54
# 7   2014   Carretera     105453.5  1885926.03
# 8   2014     Montana     101042.5  1559920.34
# 9   2014       Paseo     238086.5  3641875.37
# 10  2014         VTT     115326.0  2052025.79
# 11  2014        Velo     112123.5  1687405.21

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Get unique product names
products = table_5['Product'].unique()

# Overlay line plots for each product
for product in products:
    product_data = table_5[table_5['Product'] == product]
    ax.plot(product_data['Year'], product_data['Profit'], label=product)

# Set title and labels
ax.set_title('Profit Over Time by Product')
ax.set_xlabel('Year')
ax.set_ylabel('Profit')

# Add legend with location set to 'upper left'
ax.legend(loc='upper left')

# Show plot
plt.show()

# %%
# Group by Country and sum the metrics
table_6 = df.groupby('Country').agg({
    'Sales': 'sum',
    'Cost of Goods Sold': 'sum',
    'Discounts': 'sum',
    'Profit': 'sum'
}).reset_index()

# Print the result
print(table_6)
# Out:
#                     Country        Sales  Cost of Goods Sold   Discounts  \
# 0                    Canada  23060565.39          19914943.0  2044508.62
# 1                    France  21478327.29          18261311.5  1712562.23
# 2                   Germany  20924032.32          17828624.0  1412151.68
# 3                    Mexico  19881130.11          17107589.0  1760832.89
# 4  United States of America  24582681.18          21657021.5  2239527.85
#
#        Profit
# 0  3474599.89
# 1  3468483.29
# 2  3376400.82
# 3  3064941.11
# 4  3327464.68

# %%
# Sort the DataFrame by profit in descending order
table_6 = table_6.sort_values(by='Profit', ascending=False)

# %%
# Create a color gradient for the profit column
profits = table_6['Profit']
norm = plt.Normalize(profits.min(), profits.max())
colors = plt.cm.RdYlGn(norm(profits))


# Create a table visualization with colored profit column
fig, ax = plt.subplots(figsize=(13, 6))
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=table_6.values,
                 colLabels=table_6.columns,
                 cellLoc='center',
                 loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
for (row, col), cell in table.get_celld().items():
    if col == 4 and cell.get_text().get_text() != 'Profit':  # Check if the cell is in the Profit column
        cell.set_color(colors[row - 1])  # Use row - 1 to account for header row
# Style column headers
for (i, label) in enumerate(table_6.columns):
    table[(0, i)].set_facecolor('lightgrey')  # Set background color of column headers
    table[(0, i)].get_text().set_weight('bold')  # Make text bold for column headers

plt.title('Performance by Country')
plt.show()

# %%
# Group by Product and sum the metrics
table_7 = df.groupby('Product').agg({
    'Sales': 'sum',
    'Cost of Goods Sold': 'sum',
    'Discounts': 'sum',
    'Profit': 'sum'
}).reset_index()

# Sort the DataFrame by profit in descending order
table_7 = table_7.sort_values(by='Profit', ascending=False)
# Print the result
print(table_7)
# Out:
#        Product        Sales  Cost of Goods Sold   Discounts      Profit
# 3       Paseo   30504692.96          26218665.0  2575913.06  4527125.46
# 4         VTT   18615485.02          15984949.0  1456612.48  2874016.02
# 0    Amarilla   16012162.57          13531225.0  1284793.45  2724817.57
# 5        Velo   17221786.47          15067524.0  1576709.04  2405174.97
# 1   Carretera   13143927.89          11510368.0  1122212.62  2095779.89
# 2     Montana   14428681.38          12456758.0  1153342.62  2084975.88

# %%
# Assuming 'profits' is a column in your 'table_2' DataFrame
# Calculate the color gradient for the profit column
norm = plt.Normalize(table_7['Profit'].min(), table_7['Profit'].max())
colors = plt.cm.RdYlGn(norm(table_7['Profit']))

# Create a table visualization with colored profit column
fig, ax = plt.subplots(figsize=(13, 6))
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=table_7.values,
                 colLabels=table_7.columns,
                 cellLoc='center',
                 loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)

# Apply gradient color to the Profit column
for (row, col), cell in table.get_celld().items():
    if col == 4 and cell.get_text().get_text() != 'Profit':  # Check if the cell is in the Profit column
        cell.set_color(colors[row - 1])  # Use row - 1 to account for header row

# Style column headers
for (i, label) in enumerate(table_7.columns):
    table[(0, i)].set_facecolor('lightgrey')  # Set background color of column headers
    table[(0, i)].get_text().set_weight('bold')  # Make text bold for column headers

plt.title('Profitable Product')
plt.show()

# %%
# Group by date and sum the metrics
table_8 = df.groupby('Date').agg({
    'Cost of Goods Sold': 'sum',
    'Profit': 'sum'
}).reset_index()

# Sort the DataFrame by profit in descending order
table_8 = table_8.sort_values(by='Date', ascending=True)
# Print the result
print(table_8)
# Out:
#           Date  Cost of Goods Sold      Profit
# 0   2013-09-01           3120887.0   681950.53
# 1   2013-10-01           7555016.0  1657865.10
# 2   2013-11-01           6050465.0   752301.80
# 3   2013-12-01           4655357.0   873779.08
# 4   2014-01-01           5756873.0   902680.19
# 5   2014-02-01           4704594.0   844114.89
# 6   2014-03-01           4805900.0   670395.37
# 7   2014-04-01           5385197.5   917450.58
# 8   2014-05-01           5381571.0   942270.06
# 9   2014-06-01           7348942.0  1197434.82
# 10  2014-07-01           6491103.5   939278.19
# 11  2014-08-01           4484698.0   831803.92
# 12  2014-09-01           4802365.0   990217.74
# 13  2014-10-01          10582404.0  2013068.92
# 14  2014-11-01           4779614.0   716417.70
# 15  2014-12-01           8864502.0  1780860.90

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(10, 6))

# Plot COGS as columns
ax.bar(table_8['Date'], table_8['Cost of Goods Sold'], color='skyblue', label='COGS')

# Overlay a line plot for profit
ax.plot(table_8['Date'], table_8['Profit'], marker='o', color='green', label='Profit')

# Set title and labels
ax.set_title('COGS and Profit Over Time')
ax.set_xlabel('Date')
ax.set_ylabel('Amount')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

plt.show()

# %%
# Group by country and product and sum the profit
table_8 = df.groupby(['Country', 'Product']).agg({
    'Units Sold': 'sum'
}).reset_index()

# Sort the DataFrame by country and profit in descending order
table_8 = table_8.sort_values(by=['Country', 'Units Sold'], ascending=[False, False])

# Print the result
print(table_8)
# Out:
#                      Country      Product  Units Sold
# 27  United States of America       Paseo      67411.5
# 28  United States of America         VTT      34500.0
# 29  United States of America        Velo      32940.0
# 26  United States of America     Montana      30997.5
# 24  United States of America    Amarilla      29617.5
# 25  United States of America   Carretera      25818.0
# 21                    Mexico       Paseo      57027.0
# 18                    Mexico    Amarilla      27322.0
# 20                    Mexico     Montana      27188.0
# 22                    Mexico         VTT      26129.0
# 23                    Mexico        Velo      25047.0
# 19                    Mexico   Carretera      24754.0
# 15                   Germany       Paseo      52012.5
# 16                   Germany         VTT      27405.0
# 17                   Germany        Velo      26338.0
# 12                   Germany    Amarilla      24709.0
# 14                   Germany     Montana      23449.0
# 13                   Germany   Carretera      21222.0
# 9                     France       Paseo      68069.0
# 11                    France        Velo      34805.5
# 7                     France   Carretera      31878.0
# 10                    France         VTT      29918.5
# 8                     France     Montana      29383.0
# 6                     France    Amarilla      26954.0
# 3                     Canada       Paseo      69687.5
# 4                     Canada         VTT      37430.5
# 1                     Canada   Carretera      33185.5
# 5                     Canada        Velo      32119.0
# 0                     Canada    Amarilla      29232.0
# 2                     Canada     Montana      25960.0

# %%
# Define the custom sorting order
custom_order = ['France', 'Germany', 'Canada', 'United States of America', 'Mexico']

# Group by country and product and sum the profit
table_8= df.groupby(['Country', 'Product']).agg({
    'Units Sold': 'sum'
}).reset_index()

# Sort the DataFrame by the custom order of countries and profit in descending order
table_8['Country'] = pd.Categorical(table_8['Country'], categories=custom_order, ordered=True)
table_8= table_8.sort_values(by=['Country', 'Units Sold'], ascending=[True, False])

# Plot the bar chart
plt.figure(figsize=(10, 6))
bottoms = {}
for product in table_8['Product'].unique():
    product_data = table_8[table_8['Product'] == product]
    plt.bar(product_data['Country'], product_data['Units Sold'], bottom=bottoms.get(product, 0), label=product)
    bottoms[product] = product_data['Units Sold']

plt.xlabel('Country')
plt.ylabel('Units Sold')
plt.title('Units Sold by Country')
plt.xticks(rotation=45)
plt.legend(title='Product')

plt.show()

# %% [markdown]
# ## DATA VISUALIZATION ON WEB USING FLASK

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
#     chart_data = generate_chart()
#     return render_template('index.html', chart_data=chart_data)
    return render_template('index.html')

@app.route('/about')
def about():
    return render_template('about.html')

@app.route('/contact')
def contact():
    return render_template('contact.html')


# Dummy data for demonstration
#dummy_data = {'key': 'value'}

@app.route('/data')
def api_data():
    # Return the dummy data (replace with actual API request logic)
    return (data)


if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# [2024-04-10 10:07:31,464] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\olaka\AppData\Local\Temp\ipykernel_10664\2545793190.py", line 9, in index
#     return render_template('index.html')
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Apr/2024 10:07:31] "GET / HTTP/1.1" 500 -
# 127.0.0.1 - - [10/Apr/2024 10:07:31] "GET /favicon.ico HTTP/1.1" 404 -
# [2024-04-10 10:07:45,280] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\olaka\AppData\Local\Temp\ipykernel_10664\2545793190.py", line 9, in index
#     return render_template('index.html')
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Apr/2024 10:07:45] "GET / HTTP/1.1" 500 -
# [2024-04-10 10:07:58,353] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\olaka\AppData\Local\Temp\ipykernel_10664\2545793190.py", line 9, in index
#     return render_template('index.html')
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Apr/2024 10:07:58] "GET / HTTP/1.1" 500 -
# [2024-04-10 10:08:51,190] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\olaka\AppData\Local\Temp\ipykernel_10664\2545793190.py", line 9, in index
#     return render_template('index.html')
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Apr/2024 10:08:51] "GET / HTTP/1.1" 500 -
# [2024-04-10 10:10:26,548] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\olaka\AppData\Local\Temp\ipykernel_10664\2545793190.py", line 9, in index
#     return render_template('index.html')
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\olaka\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\olaka\anaconda3\lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Apr/2024 10:10:26] "GET / HTTP/1.1" 500 -
